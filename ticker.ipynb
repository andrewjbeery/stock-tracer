# %%
import yfinance as yf
trbcx = yf.Ticker('trbcx')
data = trbcx.funds_data

# show fund description
# data.description

# show operational information
# data.fund_overview
# data.fund_operations

# # show holdings related information
# data.asset_classes
data.top_holdings
# data.equity_holdings
# data.bond_holdings
# data.bond_ratings
# data.sector_weightings
# Out:
#                               Name  Holding Percent
# Symbol
# MSFT                Microsoft Corp         0.127215
# NVDA                   NVIDIA Corp         0.117665
# AAPL                     Apple Inc         0.093985
# AMZN                Amazon.com Inc         0.078968
# GOOG          Alphabet Inc Class C         0.058507
# META    Meta Platforms Inc Class A         0.049101
# LLY               Eli Lilly and Co         0.035240
# V                 Visa Inc Class A         0.026520
# MA          Mastercard Inc Class A         0.023474
# NOW                 ServiceNow Inc         0.021074

# %%
trbcx.
# Out:
# {'address1': 'Baltimore MD 21202',
#  'address2': '100 East Pratt Street',
#  'address3': 'T. Rowe Price Blue Chip Growth Fund, Inc',
#  'longBusinessSummary': 'The fund normally invests at least 80% of its net assets (including any borrowings for investment purposes) in the common stocks of large and medium-sized blue chip growth companies. It focuses on companies with leading market positions, seasoned management, and strong financial fundamentals. The fund is non-diversified.',
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 195.91,
#  'regularMarketPreviousClose': 195.91,
#  'trailingPE': 4.6238847,
#  'ytdReturn': 0.28177312,
#  'totalAssets': 62995652608,
#  'fiftyTwoWeekLow': 137.06,
#  'fiftyTwoWeekHigh': 197.5,
#  'fiftyDayAverage': 189.218,
#  'twoHundredDayAverage': 176.8412,
#  'trailingAnnualDividendRate': 1.96,
#  'trailingAnnualDividendYield': 0.010004594,
#  'currency': 'USD',
#  'morningStarOverallRating': 3,
#  'morningStarRiskRating': 4,
#  'annualReportExpenseRatio': 0.0069999998,
#  'beta3Year': 1.16,
#  'fundInceptionDate': 741398400,
#  'lastDividendValue': 0.11,
#  'lastCapGain': 67.0,
#  'annualHoldingsTurnover': 0.098000005,
#  'exchange': 'NAS',
#  'quoteType': 'MUTUALFUND',
#  'symbol': 'TRBCX',
#  'underlyingSymbol': 'TRBCX',
#  'shortName': 'T. Rowe Price Blue Chip Growth ',
#  'longName': 'T. Rowe Price Blue Chip Growth',
#  'firstTradeDateEpochUtc': 741447000,
#  'timeZoneFullName': 'America/New_York',
#  'timeZoneShortName': 'EDT',
#  'uuid': '1fc8fd3b-d5f1-3037-a2bd-34a978fb8b3c',
#  'messageBoardId': 'finmb_22852963',
#  'gmtOffSetMilliseconds': -14400000,
#  'trailingPegRatio': None}
